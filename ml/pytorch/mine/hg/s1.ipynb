# %%
import datasets
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoModel,
    LlamaForCausalLM,
    T5ForConditionalGeneration,
    AutoTokenizer,
    LlamaTokenizer,
    AutoModelForSequenceClassification,
)
from datasets import load_dataset
from torchinfo import summary
import torch

# %%
model = AutoModelForSequenceClassification.from_pretrained(
        "bert-large-uncased",
    )
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
summary(model,col_names=["num_params", "trainable"],row_settings=["var_names"],depth=7)
# Out:
# ========================================================================================================================
# Layer (type (var_name))                                                Param #                   Trainable
# ========================================================================================================================
# BertForSequenceClassification (BertForSequenceClassification)          --                        True
# ├─BertModel (bert)                                                     --                        True
# │    └─BertEmbeddings (embeddings)                                     --                        True
# │    │    └─Embedding (word_embeddings)                                31,254,528                True
# │    │    └─Embedding (position_embeddings)                            524,288                   True
# │    │    └─Embedding (token_type_embeddings)                          2,048                     True
# │    │    └─LayerNorm (LayerNorm)                                      2,048                     True
# │    │    └─Dropout (dropout)                                          --                        --
# │    └─BertEncoder (encoder)                                           --                        True
# │    │    └─ModuleList (layer)                                         --                        True
# │    │    │    └─BertLayer (0)                                         --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (1)                                         --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (2)                                         --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (3)                                         --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (4)                                         --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (5)                                         --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (6)                                         --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (7)                                         --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (8)                                         --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (9)                                         --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (10)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (11)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (12)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (13)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (14)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (15)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (16)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (17)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (18)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (19)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (20)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (21)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (22)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    │    │    └─BertLayer (23)                                        --                        True
# │    │    │    │    └─BertAttention (attention)                        --                        True
# │    │    │    │    │    └─BertSelfAttention (self)                    --                        True
# │    │    │    │    │    │    └─Linear (query)                         1,049,600                 True
# │    │    │    │    │    │    └─Linear (key)                           1,049,600                 True
# │    │    │    │    │    │    └─Linear (value)                         1,049,600                 True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    │    └─BertSelfOutput (output)                     --                        True
# │    │    │    │    │    │    └─Linear (dense)                         1,049,600                 True
# │    │    │    │    │    │    └─LayerNorm (LayerNorm)                  2,048                     True
# │    │    │    │    │    │    └─Dropout (dropout)                      --                        --
# │    │    │    │    └─BertIntermediate (intermediate)                  --                        True
# │    │    │    │    │    └─Linear (dense)                              4,198,400                 True
# │    │    │    │    │    └─GELUActivation (intermediate_act_fn)        --                        --
# │    │    │    │    └─BertOutput (output)                              --                        True
# │    │    │    │    │    └─Linear (dense)                              4,195,328                 True
# │    │    │    │    │    └─LayerNorm (LayerNorm)                       2,048                     True
# │    │    │    │    │    └─Dropout (dropout)                           --                        --
# │    └─BertPooler (pooler)                                             --                        True
# │    │    └─Linear (dense)                                             1,049,600                 True
# │    │    └─Tanh (activation)                                          --                        --
# ├─Dropout (dropout)                                                    --                        --
# ├─Linear (classifier)                                                  2,050                     True
# ========================================================================================================================
# Total params: 335,143,938
# Trainable params: 335,143,938
# Non-trainable params: 0
# ========================================================================================================================

# %%
transformer_model = nn.Transformer(nhead=16, num_encoder_layers=12)

# %%
summary(transformer_model,depth=9)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                                            Param #
# ==========================================================================================
# Transformer                                                       --
# ├─TransformerEncoder: 1-1                                         --
# │    └─ModuleList: 2-1                                            --
# │    │    └─TransformerEncoderLayer: 3-1                          --
# │    │    │    └─MultiheadAttention: 4-1                          787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-1        262,656
# │    │    │    └─Linear: 4-2                                      1,050,624
# │    │    │    └─Dropout: 4-3                                     --
# │    │    │    └─Linear: 4-4                                      1,049,088
# │    │    │    └─LayerNorm: 4-5                                   1,024
# │    │    │    └─LayerNorm: 4-6                                   1,024
# │    │    │    └─Dropout: 4-7                                     --
# │    │    │    └─Dropout: 4-8                                     --
# │    │    └─TransformerEncoderLayer: 3-2                          --
# │    │    │    └─MultiheadAttention: 4-9                          787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-2        262,656
# │    │    │    └─Linear: 4-10                                     1,050,624
# │    │    │    └─Dropout: 4-11                                    --
# │    │    │    └─Linear: 4-12                                     1,049,088
# │    │    │    └─LayerNorm: 4-13                                  1,024
# │    │    │    └─LayerNorm: 4-14                                  1,024
# │    │    │    └─Dropout: 4-15                                    --
# │    │    │    └─Dropout: 4-16                                    --
# │    │    └─TransformerEncoderLayer: 3-3                          --
# │    │    │    └─MultiheadAttention: 4-17                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-3        262,656
# │    │    │    └─Linear: 4-18                                     1,050,624
# │    │    │    └─Dropout: 4-19                                    --
# │    │    │    └─Linear: 4-20                                     1,049,088
# │    │    │    └─LayerNorm: 4-21                                  1,024
# │    │    │    └─LayerNorm: 4-22                                  1,024
# │    │    │    └─Dropout: 4-23                                    --
# │    │    │    └─Dropout: 4-24                                    --
# │    │    └─TransformerEncoderLayer: 3-4                          --
# │    │    │    └─MultiheadAttention: 4-25                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-4        262,656
# │    │    │    └─Linear: 4-26                                     1,050,624
# │    │    │    └─Dropout: 4-27                                    --
# │    │    │    └─Linear: 4-28                                     1,049,088
# │    │    │    └─LayerNorm: 4-29                                  1,024
# │    │    │    └─LayerNorm: 4-30                                  1,024
# │    │    │    └─Dropout: 4-31                                    --
# │    │    │    └─Dropout: 4-32                                    --
# │    │    └─TransformerEncoderLayer: 3-5                          --
# │    │    │    └─MultiheadAttention: 4-33                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-5        262,656
# │    │    │    └─Linear: 4-34                                     1,050,624
# │    │    │    └─Dropout: 4-35                                    --
# │    │    │    └─Linear: 4-36                                     1,049,088
# │    │    │    └─LayerNorm: 4-37                                  1,024
# │    │    │    └─LayerNorm: 4-38                                  1,024
# │    │    │    └─Dropout: 4-39                                    --
# │    │    │    └─Dropout: 4-40                                    --
# │    │    └─TransformerEncoderLayer: 3-6                          --
# │    │    │    └─MultiheadAttention: 4-41                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-6        262,656
# │    │    │    └─Linear: 4-42                                     1,050,624
# │    │    │    └─Dropout: 4-43                                    --
# │    │    │    └─Linear: 4-44                                     1,049,088
# │    │    │    └─LayerNorm: 4-45                                  1,024
# │    │    │    └─LayerNorm: 4-46                                  1,024
# │    │    │    └─Dropout: 4-47                                    --
# │    │    │    └─Dropout: 4-48                                    --
# │    │    └─TransformerEncoderLayer: 3-7                          --
# │    │    │    └─MultiheadAttention: 4-49                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-7        262,656
# │    │    │    └─Linear: 4-50                                     1,050,624
# │    │    │    └─Dropout: 4-51                                    --
# │    │    │    └─Linear: 4-52                                     1,049,088
# │    │    │    └─LayerNorm: 4-53                                  1,024
# │    │    │    └─LayerNorm: 4-54                                  1,024
# │    │    │    └─Dropout: 4-55                                    --
# │    │    │    └─Dropout: 4-56                                    --
# │    │    └─TransformerEncoderLayer: 3-8                          --
# │    │    │    └─MultiheadAttention: 4-57                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-8        262,656
# │    │    │    └─Linear: 4-58                                     1,050,624
# │    │    │    └─Dropout: 4-59                                    --
# │    │    │    └─Linear: 4-60                                     1,049,088
# │    │    │    └─LayerNorm: 4-61                                  1,024
# │    │    │    └─LayerNorm: 4-62                                  1,024
# │    │    │    └─Dropout: 4-63                                    --
# │    │    │    └─Dropout: 4-64                                    --
# │    │    └─TransformerEncoderLayer: 3-9                          --
# │    │    │    └─MultiheadAttention: 4-65                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-9        262,656
# │    │    │    └─Linear: 4-66                                     1,050,624
# │    │    │    └─Dropout: 4-67                                    --
# │    │    │    └─Linear: 4-68                                     1,049,088
# │    │    │    └─LayerNorm: 4-69                                  1,024
# │    │    │    └─LayerNorm: 4-70                                  1,024
# │    │    │    └─Dropout: 4-71                                    --
# │    │    │    └─Dropout: 4-72                                    --
# │    │    └─TransformerEncoderLayer: 3-10                         --
# │    │    │    └─MultiheadAttention: 4-73                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-10       262,656
# │    │    │    └─Linear: 4-74                                     1,050,624
# │    │    │    └─Dropout: 4-75                                    --
# │    │    │    └─Linear: 4-76                                     1,049,088
# │    │    │    └─LayerNorm: 4-77                                  1,024
# │    │    │    └─LayerNorm: 4-78                                  1,024
# │    │    │    └─Dropout: 4-79                                    --
# │    │    │    └─Dropout: 4-80                                    --
# │    │    └─TransformerEncoderLayer: 3-11                         --
# │    │    │    └─MultiheadAttention: 4-81                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-11       262,656
# │    │    │    └─Linear: 4-82                                     1,050,624
# │    │    │    └─Dropout: 4-83                                    --
# │    │    │    └─Linear: 4-84                                     1,049,088
# │    │    │    └─LayerNorm: 4-85                                  1,024
# │    │    │    └─LayerNorm: 4-86                                  1,024
# │    │    │    └─Dropout: 4-87                                    --
# │    │    │    └─Dropout: 4-88                                    --
# │    │    └─TransformerEncoderLayer: 3-12                         --
# │    │    │    └─MultiheadAttention: 4-89                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-12       262,656
# │    │    │    └─Linear: 4-90                                     1,050,624
# │    │    │    └─Dropout: 4-91                                    --
# │    │    │    └─Linear: 4-92                                     1,049,088
# │    │    │    └─LayerNorm: 4-93                                  1,024
# │    │    │    └─LayerNorm: 4-94                                  1,024
# │    │    │    └─Dropout: 4-95                                    --
# │    │    │    └─Dropout: 4-96                                    --
# │    └─LayerNorm: 2-2                                             1,024
# ├─TransformerDecoder: 1-2                                         --
# │    └─ModuleList: 2-3                                            --
# │    │    └─TransformerDecoderLayer: 3-13                         --
# │    │    │    └─MultiheadAttention: 4-97                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-13       262,656
# │    │    │    └─MultiheadAttention: 4-98                         787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-14       262,656
# │    │    │    └─Linear: 4-99                                     1,050,624
# │    │    │    └─Dropout: 4-100                                   --
# │    │    │    └─Linear: 4-101                                    1,049,088
# │    │    │    └─LayerNorm: 4-102                                 1,024
# │    │    │    └─LayerNorm: 4-103                                 1,024
# │    │    │    └─LayerNorm: 4-104                                 1,024
# │    │    │    └─Dropout: 4-105                                   --
# │    │    │    └─Dropout: 4-106                                   --
# │    │    │    └─Dropout: 4-107                                   --
# │    │    └─TransformerDecoderLayer: 3-14                         --
# │    │    │    └─MultiheadAttention: 4-108                        787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-15       262,656
# │    │    │    └─MultiheadAttention: 4-109                        787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-16       262,656
# │    │    │    └─Linear: 4-110                                    1,050,624
# │    │    │    └─Dropout: 4-111                                   --
# │    │    │    └─Linear: 4-112                                    1,049,088
# │    │    │    └─LayerNorm: 4-113                                 1,024
# │    │    │    └─LayerNorm: 4-114                                 1,024
# │    │    │    └─LayerNorm: 4-115                                 1,024
# │    │    │    └─Dropout: 4-116                                   --
# │    │    │    └─Dropout: 4-117                                   --
# │    │    │    └─Dropout: 4-118                                   --
# │    │    └─TransformerDecoderLayer: 3-15                         --
# │    │    │    └─MultiheadAttention: 4-119                        787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-17       262,656
# │    │    │    └─MultiheadAttention: 4-120                        787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-18       262,656
# │    │    │    └─Linear: 4-121                                    1,050,624
# │    │    │    └─Dropout: 4-122                                   --
# │    │    │    └─Linear: 4-123                                    1,049,088
# │    │    │    └─LayerNorm: 4-124                                 1,024
# │    │    │    └─LayerNorm: 4-125                                 1,024
# │    │    │    └─LayerNorm: 4-126                                 1,024
# │    │    │    └─Dropout: 4-127                                   --
# │    │    │    └─Dropout: 4-128                                   --
# │    │    │    └─Dropout: 4-129                                   --
# │    │    └─TransformerDecoderLayer: 3-16                         --
# │    │    │    └─MultiheadAttention: 4-130                        787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-19       262,656
# │    │    │    └─MultiheadAttention: 4-131                        787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-20       262,656
# │    │    │    └─Linear: 4-132                                    1,050,624
# │    │    │    └─Dropout: 4-133                                   --
# │    │    │    └─Linear: 4-134                                    1,049,088
# │    │    │    └─LayerNorm: 4-135                                 1,024
# │    │    │    └─LayerNorm: 4-136                                 1,024
# │    │    │    └─LayerNorm: 4-137                                 1,024
# │    │    │    └─Dropout: 4-138                                   --
# │    │    │    └─Dropout: 4-139                                   --
# │    │    │    └─Dropout: 4-140                                   --
# │    │    └─TransformerDecoderLayer: 3-17                         --
# │    │    │    └─MultiheadAttention: 4-141                        787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-21       262,656
# │    │    │    └─MultiheadAttention: 4-142                        787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-22       262,656
# │    │    │    └─Linear: 4-143                                    1,050,624
# │    │    │    └─Dropout: 4-144                                   --
# │    │    │    └─Linear: 4-145                                    1,049,088
# │    │    │    └─LayerNorm: 4-146                                 1,024
# │    │    │    └─LayerNorm: 4-147                                 1,024
# │    │    │    └─LayerNorm: 4-148                                 1,024
# │    │    │    └─Dropout: 4-149                                   --
# │    │    │    └─Dropout: 4-150                                   --
# │    │    │    └─Dropout: 4-151                                   --
# │    │    └─TransformerDecoderLayer: 3-18                         --
# │    │    │    └─MultiheadAttention: 4-152                        787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-23       262,656
# │    │    │    └─MultiheadAttention: 4-153                        787,968
# │    │    │    │    └─NonDynamicallyQuantizableLinear: 5-24       262,656
# │    │    │    └─Linear: 4-154                                    1,050,624
# │    │    │    └─Dropout: 4-155                                   --
# │    │    │    └─Linear: 4-156                                    1,049,088
# │    │    │    └─LayerNorm: 4-157                                 1,024
# │    │    │    └─LayerNorm: 4-158                                 1,024
# │    │    │    └─LayerNorm: 4-159                                 1,024
# │    │    │    └─Dropout: 4-160                                   --
# │    │    │    └─Dropout: 4-161                                   --
# │    │    │    └─Dropout: 4-162                                   --
# │    └─LayerNorm: 2-4                                             1,024
# ==========================================================================================
# Total params: 63,054,848
# Trainable params: 63,054,848
# Non-trainable params: 0
# ==========================================================================================
